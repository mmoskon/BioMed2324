# %% [markdown]
# ## Getting started

# %%
import pandas as pd
import cobra

from cobra.io import load_model

import numpy as np
import pickle

import os.path 

import matplotlib.pyplot as plt
import seaborn as sns

from IPython.core.display import HTML

# %% [markdown]
# ## *E. coli*

# %% [markdown]
# We will read an *E. coli* metabolic model. The model has been downloaded from http://bigg.ucsd.edu/models/e_coli_core.

# %%
model = cobra.io.read_sbml_model(os.path.join('models','e_coli_core.xml'))

# %%
model
# Out:
# <Model e_coli_core at 0x2b0446a7510>

# %%
model.reactions[0]
# Out:
# <Reaction PFK at 0x2b044881d10>

# %% [markdown]
# Let's define the biommas function as the metabolic objective:

# %%
model.reactions.get_by_id('BIOMASS_Ecoli_core_w_GAM')
# Out:
# <Reaction BIOMASS_Ecoli_core_w_GAM at 0x2b0448a6910>

# %%
r_biomass = model.reactions.get_by_id('BIOMASS_Ecoli_core_w_GAM')
r_biomass
# Out:
# <Reaction BIOMASS_Ecoli_core_w_GAM at 0x2b0448a6910>

# %%
model.objective = r_biomass

# %%
model.objective.expression
# Out:
# 1.0*BIOMASS_Ecoli_core_w_GAM - 1.0*BIOMASS_Ecoli_core_w_GAM_reverse_712e5

# %%
sol = model.optimize()
sol
# Out:
# <Solution 0.874 at 0x2b0448ee490>

# %%
model.summary()
# Out:
# <h3>Objective</h3><p>1.0 BIOMASS_Ecoli_core_w_GAM = 0.8739215069684311</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>glc__D_e</td>
#       <td>EX_glc__D_e</td>
#       <td>10</td>
#       <td>6</td>
#       <td>100.00%</td>
#     </tr>
#     <tr>
#       <td>nh4_e</td>
#       <td>EX_nh4_e</td>
#       <td>4.765</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>o2_e</td>
#       <td>EX_o2_e</td>
#       <td>21.8</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>pi_e</td>
#       <td>EX_pi_e</td>
#       <td>3.215</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>co2_e</td>
#       <td>EX_co2_e</td>
#       <td>-22.81</td>
#       <td>1</td>
#       <td>100.00%</td>
#     </tr>
#     <tr>
#       <td>h2o_e</td>
#       <td>EX_h2o_e</td>
#       <td>-29.18</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>h_e</td>
#       <td>EX_h_e</td>
#       <td>-17.53</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# We can see that the cell growth equals 0.874 $h^{-1}$.

# %% [markdown]
# We can compare this with the result obtained using [Escher-FBA](https://sbrg.github.io/escher-fba/#/app):

# %%
sol = model.optimize()
sol['EX_glc__D_e']
# Out:
# -10.0

# %%
sol = model.optimize()
sol['EX_o2_e']
# Out:
# -21.79949265599876

# %% [markdown]
# ### Growth medium

# %% [markdown]
# We can try changing the medium composition. As we see above, the cell consumes a significant amount of glucose (the flux through *EX_glc__D_e* equals 10 $mmol gDW^{-1} hr^{-1}$ -- millimole per gram dry weight per hour - default units in COBRA). What is the maximal possible uptake of glucose? Does the cell consume everything that is available?

# %%
r_ex_glc = model.reactions.get_by_id('EX_glc__D_e')
r_ex_glc
# Out:
# <Reaction EX_glc__D_e at 0x2b0448fd910>

# %% [markdown]
# We can see that the flux is negative. However, the reaction is reversed (glucose secretion)! In COBRA all *exchange* (*uptake* and *secretion*) reactions have such form.
#
# As we can see the cell consumes all the glucose that is available. Let's try to reduce the glucose in the medium.

# %%
r_ex_glc.bounds
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 r_ex_glc.bounds
#
# NameError: name 'r_ex_glc' is not defined

# %%
r_ex_glc.bounds = (0, 1000.0)
model.optimize()
# Out:
# C:\Users\miham\.conda\envs\metabolic\Lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# <Solution infeasible at 0x2b0448d97d0>

# %% [markdown]
# Oh no. This was too much. Let's be a little bit more permissive.

# %%
r_ex_glc.bounds = (-1.0, 1000.0)

# %%
model.optimize()
# Out:
# <Solution 0.048 at 0x2b0448db6d0>

# %% [markdown]
# We can repeat a similar analysis in anaerobic conditions. We will remove the oxygen by setting its *uptake* bounds to 0:

# %%
r_ex_o2 = model.reactions.get_by_id('EX_o2_e')
r_ex_o2
# Out:
# <Reaction EX_o2_e at 0x2b044904290>

# %%
r_ex_glc.bounds = (-10.0, 1000.0)
r_ex_o2.bounds = (0, 1000)

# %%
model.summary()
# Out:
# <h3>Objective</h3><p>1.0 BIOMASS_Ecoli_core_w_GAM = 0.21166294973531086</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>co2_e</td>
#       <td>EX_co2_e</td>
#       <td>0.3782</td>
#       <td>1</td>
#       <td>0.63%</td>
#     </tr>
#     <tr>
#       <td>glc__D_e</td>
#       <td>EX_glc__D_e</td>
#       <td>10</td>
#       <td>6</td>
#       <td>99.37%</td>
#     </tr>
#     <tr>
#       <td>h2o_e</td>
#       <td>EX_h2o_e</td>
#       <td>7.116</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>nh4_e</td>
#       <td>EX_nh4_e</td>
#       <td>1.154</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>pi_e</td>
#       <td>EX_pi_e</td>
#       <td>0.7786</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>ac_e</td>
#       <td>EX_ac_e</td>
#       <td>-8.504</td>
#       <td>2</td>
#       <td>33.11%</td>
#     </tr>
#     <tr>
#       <td>etoh_e</td>
#       <td>EX_etoh_e</td>
#       <td>-8.279</td>
#       <td>2</td>
#       <td>32.23%</td>
#     </tr>
#     <tr>
#       <td>for_e</td>
#       <td>EX_for_e</td>
#       <td>-17.8</td>
#       <td>1</td>
#       <td>34.66%</td>
#     </tr>
#     <tr>
#       <td>h_e</td>
#       <td>EX_h_e</td>
#       <td>-30.55</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Biomass production has dropped. Also, alternative pathway is now used for energy productions. The cell is now generating and secreting acetate (`ac`), formate (`for`) and ethanol (`etoh`). Before, the cell has been secreting water and carbon dioxide (cellular respiration).

# %% [markdown]
# We can further analyse biomass production rate in dependence on oxygen and glucose:

# %%
o2_max = 1500
glc_max = 1000

# we generate a sorted list of oxygen and glucose values
o2_range = np.arange(0, o2_max+1,100)
glc_range = np.arange(0, glc_max+1,100)

# a matrix with two rows; one for oxygen and one for glucose
B = np.zeros((len(o2_range),len(glc_range)))

# for each pair of values of O2 and glc we calculate and save the biomass production rate
for i,o2 in enumerate(o2_range):
    for j,glc in enumerate(glc_range):
        r_ex_o2.lower_bound = -o2 # setting the oxygen uptake value
        r_ex_glc.lower_bound = -glc # setting the glucose uptake value
        s = model.optimize()
        B[i,j] = s.objective_value # saving the result
# Out:
# C:\Users\miham\.conda\envs\metabolic\Lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# C:\Users\miham\.conda\envs\metabolic\Lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# C:\Users\miham\.conda\envs\metabolic\Lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# C:\Users\miham\.conda\envs\metabolic\Lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# C:\Users\miham\.conda\envs\metabolic\Lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# C:\Users\miham\.conda\envs\metabolic\Lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# C:\Users\miham\.conda\envs\metabolic\Lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# C:\Users\miham\.conda\envs\metabolic\Lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# C:\Users\miham\.conda\envs\metabolic\Lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# C:\Users\miham\.conda\envs\metabolic\Lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# C:\Users\miham\.conda\envs\metabolic\Lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# C:\Users\miham\.conda\envs\metabolic\Lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# C:\Users\miham\.conda\envs\metabolic\Lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# C:\Users\miham\.conda\envs\metabolic\Lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# C:\Users\miham\.conda\envs\metabolic\Lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# C:\Users\miham\.conda\envs\metabolic\Lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)

# %%
ax = sns.heatmap(B, xticklabels=glc_range, yticklabels=o2_range)
ax.invert_yaxis()
plt.xlabel("glc")
plt.ylabel("o2")
plt.show()

# %% [markdown]
# ## FVA
# FVA (Flux Variability Analysis) allows the analysis of flux ranges bringing the system to almost optimal biomass production.

# %%
from cobra.flux_analysis import flux_variability_analysis

# %%
fva = flux_variability_analysis(model, fraction_of_optimum=0.9, loopless=True)

# %%
fva
# Out:
#              minimum      maximum
# PFK       356.265728   510.972296
# PFL         0.000000   385.309865
# PGI        67.205944   522.310700
# PGK     -1000.000000  -757.862000
# PGL        16.445872   560.689093
# ...              ...          ...
# NADH16    795.108259  1000.000000
# NADTRHD     0.000000   595.977463
# NH4t      167.087855   266.791737
# O2t       397.554130   500.000000
# PDH       317.320139   870.886213
#
# [95 rows x 2 columns]

# %%
model.optimize()
model.summary(fva=0.90)
# Out:
# <h3>Objective</h3><p>1.0 BIOMASS_Ecoli_core_w_GAM = 34.04731003781035</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>Range</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>glc__D_e</td>
#       <td>EX_glc__D_e</td>
#       <td>575.2</td>
#       <td>[447.9;  634.2]</td>
#       <td>6</td>
#       <td>100.00%</td>
#     </tr>
#     <tr>
#       <td>nh4_e</td>
#       <td>EX_nh4_e</td>
#       <td>185.7</td>
#       <td>[167.1;  266.8]</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>o2_e</td>
#       <td>EX_o2_e</td>
#       <td>500</td>
#       <td>[397.6;  500]</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>pi_e</td>
#       <td>EX_pi_e</td>
#       <td>125.2</td>
#       <td>[112.7;  125.2]</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>Range</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>ac_e</td>
#       <td>EX_ac_e</td>
#       <td>-276.3</td>
#       <td>[-385.3;  0]</td>
#       <td>2</td>
#       <td>27.59%</td>
#     </tr>
#     <tr>
#       <td>acald_e</td>
#       <td>EX_acald_e</td>
#       <td>0</td>
#       <td>[-555.1;  0]</td>
#       <td>2</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>akg_e</td>
#       <td>EX_akg_e</td>
#       <td>0</td>
#       <td>[-99.7;  0]</td>
#       <td>5</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>co2_e</td>
#       <td>EX_co2_e</td>
#       <td>-815.8</td>
#       <td>[-1000;  -539.3]</td>
#       <td>1</td>
#       <td>40.74%</td>
#     </tr>
#     <tr>
#       <td>etoh_e</td>
#       <td>EX_etoh_e</td>
#       <td>-296.8</td>
#       <td>[-566.2;  0]</td>
#       <td>2</td>
#       <td>29.64%</td>
#     </tr>
#     <tr>
#       <td>for_e</td>
#       <td>EX_for_e</td>
#       <td>-40.73</td>
#       <td>[-385.3;  0]</td>
#       <td>1</td>
#       <td>2.03%</td>
#     </tr>
#     <tr>
#       <td>glu__L_e</td>
#       <td>EX_glu__L_e</td>
#       <td>0</td>
#       <td>[-99.7;  0]</td>
#       <td>5</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>h2o_e</td>
#       <td>EX_h2o_e</td>
#       <td>-767</td>
#       <td>[-985.2;  -535.5]</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>h_e</td>
#       <td>EX_h_e</td>
#       <td>-1000</td>
#       <td>[-1000;  -614.7]</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>lac__D_e</td>
#       <td>EX_lac__D_e</td>
#       <td>0</td>
#       <td>[-385.3;  0]</td>
#       <td>3</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>pyr_e</td>
#       <td>EX_pyr_e</td>
#       <td>0</td>
#       <td>[-365.1;  0]</td>
#       <td>3</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>succ_e</td>
#       <td>EX_succ_e</td>
#       <td>0</td>
#       <td>[-119.5;  0]</td>
#       <td>4</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Genes in the model

# %%
for r in model.reactions:
    print(r.gpr)
# Out:
# b3916 or b1723
# ((b0902 and b0903) and b2579) or (b0902 and b0903) or (b0902 and b3114) or (b3951 and b3952)
# b4025
# b2926
# b0767
# b0351 or b1241
# b2587
# b3612 or b4395 or b0755
# b2987 or b3493
# b0356 or b1478 or b1241
# s0001
# b3115 or b2296 or b1849
# b3956
# b0118 or b1276
# b0118 or b1276
#
# b3403
#
# b1702
# b0474
# b0116 and b0726 and b0727
# ((b3736 and b3737 and b3738) and (b3731 and b3732 and b3733 and b3734 and b3735)) or ((b3736 and b3737 and b3738) and (b3731 and b3732 and b3733 and b3734 and b3735) and b3739)
# b2297 or b2458
# b1854 or b1676
#
#
# s0001
# b3386 or b4301
# b0720
# b2914 or b4090
# b3528
# (b0978 and b0979) or (b0733 and b0734)
# b2975 or b3603
# b2779
#
#
# b0721 and b0722 and b0723 and b0724
# b0728 and b0729
# b2464 or b0008
# b1602 and b1603
# b2935 or b2465
# b2935 or b2465
# b3919
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# b2097 or b1773 or b2925
# b3925 or b4232
# b0904 or b2492
# b0904 or b2492
# b4151 and b4152 and b4153 and b4154
# b1817 and b1818 and b1819 and b2415 and b2416
# b1612 or b4122 or b1611
# b3528
# b1852
# b1779
# (b2417 and b1101 and b2415 and b2416) or (b1817 and b1818 and b1819 and b2415 and b2416) or (b2417 and b1621 and b2415 and b2416)
# b3870 or b1297
# b0811 and b0810 and b0809
# b1761
# b1812 or b0485 or b1524
# b3212 and b3213
# b4077
# b2029
# b0875 or s0001
# b1136
# b4015
# b2133 or b1380
# b4014 or b2976
# b3528
# b3236
# b1479
# b2463
# b2276 and b2277 and b2278 and b2279 and b2280 and b2281 and b2282 and b2283 and b2284 and b2285 and b2286 and b2287 and b2288
# b3962 or (b1602 and b1603)
# s0001 or b0451
# s0001
# b0114 and b0115 and b0116

# %%
model.genes.get_by_id('b4015')
# Out:
# <Gene b4015 at 0x2b04485c110>

# %% [markdown]
# ## Recon3D

# %% [markdown]
# Recon3D presents a human metabolic model. The model has been downloaded from [https://github.com/SBRG/Recon3D](https://github.com/SBRG/Recon3D). The model is described in the paper available [here](http://dx.doi.org/10.1038/nbt.4072).

# %%
model_rec3d = cobra.io.read_sbml_model(os.path.join('models','Recon3D.xml'))

# %%
model_rec3d
# Out:
# <Model Recon3D at 0x2b0449fae50>

# %% [markdown]
# Some of the model attributes:

# %%
model_rec3d.genes[0]
# Out:
# <Gene 0 at 0x2b044b95190>

# %%
model_rec3d.metabolites[:3]
# Out:
# [<Metabolite 10fthf_c at 0x2b046db5a50>,
#  <Metabolite 10fthf_l at 0x2b044b52fd0>,
#  <Metabolite 10fthf_m at 0x2b044b79350>]

# %%
model_rec3d.reactions[:3]
# Out:
# [<Reaction 24_25DHVITD3tm at 0x2b0724869d0>,
#  <Reaction 25HVITD3t at 0x2b046d99110>,
#  <Reaction COAtl at 0x2b072487310>]

# %% [markdown]
# The model summary can be obtained with the method [summary](https://cobrapy.readthedocs.io/en/latest/autoapi/cobra/summary/model_summary/index.html):

# %%
model_rec3d.summary()
# Out:
# <h3>Objective</h3><p>1.0 BIOMASS_maintenance = 755.0032155506632</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>thmtp_c</td>
#       <td>DM_thmtp_c</td>
#       <td>1000</td>
#       <td>12</td>
#       <td>4.10%</td>
#     </tr>
#     <tr>
#       <td>12ppd__R_e</td>
#       <td>EX_12ppd__R_e</td>
#       <td>250.8</td>
#       <td>3</td>
#       <td>0.26%</td>
#     </tr>
#     <tr>
#       <td>5aop_e</td>
#       <td>EX_5aop_e</td>
#       <td>1000</td>
#       <td>5</td>
#       <td>1.71%</td>
#     </tr>
#     <tr>
#       <td>HC00250_e</td>
#       <td>EX_HC00250_e</td>
#       <td>1000</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>HC00900_e</td>
#       <td>EX_HC00900_e</td>
#       <td>1000</td>
#       <td>4</td>
#       <td>1.37%</td>
#     </tr>
#     <tr>
#       <td>HC01361_e</td>
#       <td>EX_HC01361_e</td>
#       <td>1000</td>
#       <td>9</td>
#       <td>3.08%</td>
#     </tr>
#     <tr>
#       <td>Lkynr_e</td>
#       <td>EX_Lkynr_e</td>
#       <td>105.1</td>
#       <td>10</td>
#       <td>0.36%</td>
#     </tr>
#     <tr>
#       <td>acetone_e</td>
#       <td>EX_acetone_e</td>
#       <td>427.7</td>
#       <td>3</td>
#       <td>0.44%</td>
#     </tr>
#     <tr>
#       <td>alltn_e</td>
#       <td>EX_alltn_e</td>
#       <td>1000</td>
#       <td>4</td>
#       <td>1.37%</td>
#     </tr>
#     <tr>
#       <td>atp_e</td>
#       <td>EX_atp_e</td>
#       <td>1000</td>
#       <td>10</td>
#       <td>3.42%</td>
#     </tr>
#     <tr>
#       <td>cbasp_e</td>
#       <td>EX_cbasp_e</td>
#       <td>266.2</td>
#       <td>5</td>
#       <td>0.45%</td>
#     </tr>
#     <tr>
#       <td>chsterol_e</td>
#       <td>EX_chsterol_e</td>
#       <td>154.3</td>
#       <td>27</td>
#       <td>1.42%</td>
#     </tr>
#     <tr>
#       <td>cit_e</td>
#       <td>EX_cit_e</td>
#       <td>718.8</td>
#       <td>6</td>
#       <td>1.47%</td>
#     </tr>
#     <tr>
#       <td>crm_hs_e</td>
#       <td>EX_crm_hs_e</td>
#       <td>1000</td>
#       <td>19</td>
#       <td>6.49%</td>
#     </tr>
#     <tr>
#       <td>dcmp_e</td>
#       <td>EX_dcmp_e</td>
#       <td>1000</td>
#       <td>9</td>
#       <td>3.08%</td>
#     </tr>
#     <tr>
#       <td>dopa_e</td>
#       <td>EX_dopa_e</td>
#       <td>1000</td>
#       <td>8</td>
#       <td>2.73%</td>
#     </tr>
#     <tr>
#       <td>dtmp_e</td>
#       <td>EX_dtmp_e</td>
#       <td>1000</td>
#       <td>10</td>
#       <td>3.42%</td>
#     </tr>
#     <tr>
#       <td>gluside_hs_e</td>
#       <td>EX_gluside_hs_e</td>
#       <td>13.2</td>
#       <td>25</td>
#       <td>0.11%</td>
#     </tr>
#     <tr>
#       <td>h2o2_e</td>
#       <td>EX_h2o2_e</td>
#       <td>1000</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>hmcr_e</td>
#       <td>EX_hmcr_e</td>
#       <td>733.8</td>
#       <td>7</td>
#       <td>1.76%</td>
#     </tr>
#     <tr>
#       <td>inost_e</td>
#       <td>EX_inost_e</td>
#       <td>777.8</td>
#       <td>6</td>
#       <td>1.60%</td>
#     </tr>
#     <tr>
#       <td>o2_e</td>
#       <td>EX_o2_e</td>
#       <td>1000</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>o2s_e</td>
#       <td>EX_o2s_e</td>
#       <td>1000</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>ocdca_e</td>
#       <td>EX_ocdca_e</td>
#       <td>138.9</td>
#       <td>18</td>
#       <td>0.85%</td>
#     </tr>
#     <tr>
#       <td>pe_hs_e</td>
#       <td>EX_pe_hs_e</td>
#       <td>41.81</td>
#       <td>7</td>
#       <td>0.10%</td>
#     </tr>
#     <tr>
#       <td>pep_e</td>
#       <td>EX_pep_e</td>
#       <td>1000</td>
#       <td>3</td>
#       <td>1.03%</td>
#     </tr>
#     <tr>
#       <td>pglyc_hs_e</td>
#       <td>EX_pglyc_hs_e</td>
#       <td>11</td>
#       <td>8</td>
#       <td>0.03%</td>
#     </tr>
#     <tr>
#       <td>ps_hs_e</td>
#       <td>EX_ps_hs_e</td>
#       <td>920.8</td>
#       <td>8</td>
#       <td>2.52%</td>
#     </tr>
#     <tr>
#       <td>udpglcur_e</td>
#       <td>EX_udpglcur_e</td>
#       <td>1000</td>
#       <td>15</td>
#       <td>5.13%</td>
#     </tr>
#     <tr>
#       <td>utp_e</td>
#       <td>EX_utp_e</td>
#       <td>1000</td>
#       <td>9</td>
#       <td>3.08%</td>
#     </tr>
#     <tr>
#       <td>xtsn_e</td>
#       <td>EX_xtsn_e</td>
#       <td>1000</td>
#       <td>10</td>
#       <td>3.42%</td>
#     </tr>
#     <tr>
#       <td>arg__L_c</td>
#       <td>SK_arg__L_c</td>
#       <td>577.6</td>
#       <td>6</td>
#       <td>1.18%</td>
#     </tr>
#     <tr>
#       <td>asn__L_c</td>
#       <td>SK_asn__L_c</td>
#       <td>693.4</td>
#       <td>4</td>
#       <td>0.95%</td>
#     </tr>
#     <tr>
#       <td>chol_c</td>
#       <td>SK_chol_c</td>
#       <td>129.8</td>
#       <td>5</td>
#       <td>0.22%</td>
#     </tr>
#     <tr>
#       <td>cholate_c</td>
#       <td>SK_cholate_c</td>
#       <td>853</td>
#       <td>24</td>
#       <td>7.00%</td>
#     </tr>
#     <tr>
#       <td>dchac_c</td>
#       <td>SK_dchac_c</td>
#       <td>147</td>
#       <td>24</td>
#       <td>1.21%</td>
#     </tr>
#     <tr>
#       <td>gln__L_c</td>
#       <td>SK_gln__L_c</td>
#       <td>246.1</td>
#       <td>5</td>
#       <td>0.42%</td>
#     </tr>
#     <tr>
#       <td>glu__L_c</td>
#       <td>SK_glu__L_c</td>
#       <td>457</td>
#       <td>5</td>
#       <td>0.78%</td>
#     </tr>
#     <tr>
#       <td>glygn2_c</td>
#       <td>SK_glygn2_c</td>
#       <td>850.3</td>
#       <td>66</td>
#       <td>19.18%</td>
#     </tr>
#     <tr>
#       <td>his__L_c</td>
#       <td>SK_his__L_c</td>
#       <td>108</td>
#       <td>6</td>
#       <td>0.22%</td>
#     </tr>
#     <tr>
#       <td>ile__L_c</td>
#       <td>SK_ile__L_c</td>
#       <td>216</td>
#       <td>6</td>
#       <td>0.44%</td>
#     </tr>
#     <tr>
#       <td>leu__L_c</td>
#       <td>SK_leu__L_c</td>
#       <td>411.9</td>
#       <td>6</td>
#       <td>0.84%</td>
#     </tr>
#     <tr>
#       <td>met__L_c</td>
#       <td>SK_met__L_c</td>
#       <td>1000</td>
#       <td>5</td>
#       <td>1.71%</td>
#     </tr>
#     <tr>
#       <td>nad_c</td>
#       <td>SK_nad_c</td>
#       <td>1000</td>
#       <td>21</td>
#       <td>7.18%</td>
#     </tr>
#     <tr>
#       <td>phe__L_c</td>
#       <td>SK_phe__L_c</td>
#       <td>195.9</td>
#       <td>9</td>
#       <td>0.60%</td>
#     </tr>
#     <tr>
#       <td>pro__L_c</td>
#       <td>SK_pro__L_c</td>
#       <td>311.4</td>
#       <td>5</td>
#       <td>0.53%</td>
#     </tr>
#     <tr>
#       <td>thr__L_c</td>
#       <td>SK_thr__L_c</td>
#       <td>236.1</td>
#       <td>4</td>
#       <td>0.32%</td>
#     </tr>
#     <tr>
#       <td>tmndnccoa_c</td>
#       <td>SK_tmndnccoa_c</td>
#       <td>111.1</td>
#       <td>41</td>
#       <td>1.56%</td>
#     </tr>
#     <tr>
#       <td>trp__L_c</td>
#       <td>SK_trp__L_c</td>
#       <td>10.05</td>
#       <td>11</td>
#       <td>0.04%</td>
#     </tr>
#     <tr>
#       <td>tyr__L_c</td>
#       <td>SK_tyr__L_c</td>
#       <td>120.6</td>
#       <td>9</td>
#       <td>0.37%</td>
#     </tr>
#     <tr>
#       <td>val__L_c</td>
#       <td>SK_val__L_c</td>
#       <td>266.2</td>
#       <td>5</td>
#       <td>0.45%</td>
#     </tr>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>C02712_c</td>
#       <td>DM_C02712_c</td>
#       <td>-884.5</td>
#       <td>7</td>
#       <td>2.36%</td>
#     </tr>
#     <tr>
#       <td>dca24g_c</td>
#       <td>DM_dca24g_c</td>
#       <td>-1000</td>
#       <td>30</td>
#       <td>11.43%</td>
#     </tr>
#     <tr>
#       <td>kynate_c</td>
#       <td>DM_kynate_c</td>
#       <td>-105.1</td>
#       <td>10</td>
#       <td>0.40%</td>
#     </tr>
#     <tr>
#       <td>C09642_e</td>
#       <td>EX_C09642_e</td>
#       <td>-1000</td>
#       <td>10</td>
#       <td>3.81%</td>
#     </tr>
#     <tr>
#       <td>M01966_e</td>
#       <td>EX_M01966_e</td>
#       <td>-550.9</td>
#       <td>6</td>
#       <td>1.26%</td>
#     </tr>
#     <tr>
#       <td>Rtotal_e</td>
#       <td>EX_Rtotal_e</td>
#       <td>-1000</td>
#       <td>1</td>
#       <td>0.38%</td>
#     </tr>
#     <tr>
#       <td>ade_e</td>
#       <td>EX_ade_e</td>
#       <td>-616.3</td>
#       <td>5</td>
#       <td>1.17%</td>
#     </tr>
#     <tr

# %%
for r in model_rec3d.reactions[:100]:
    gpr = r.gene_reaction_rule
    if gpr:
        print(gpr)
# Out:
# 1591_AT1
# 8639_AT1 or 26_AT1 or 314_AT2 or 314_AT1
# 1594_AT1
# 10993_AT1
# 6818_AT1
# 89874_AT1
# (4967_AT2 and 1738_AT1 and 8050_AT1 and 1743_AT1) or (4967_AT1 and 1738_AT1 and 8050_AT1 and 1743_AT1)
# 89874_AT1
# 117247_AT1
# 221_AT1 or 218_AT1 or 220_AT1
# 18_AT1 or 18_AT2
# 23498_AT1
# 4128_AT1 or 4129_AT1
# 4129_AT1 or 8639_AT1 or 26_AT1 or 314_AT2 or 314_AT1 or 4128_AT1
# 222_AT1 or 220_AT1 or 221_AT1 or 218_AT1
# 6799_AT1 or 6817_AT3 or 6799_AT2 or 6818_AT2 or 6817_AT2 or 6818_AT1 or 6817_AT1 or 6817_AT4 or 6818_AT3 or 6817_AT5
# 6822_AT1 or 6818_AT1
# 6573_AT1 or 6573_AT2
# 4128_AT1 or 4129_AT1
# 53947_AT1
# 53947_AT1
# 51146_AT1
# 28_AT1
# 28_AT1
# 28_AT1
# 28_AT1
# 28_AT1
# 28_AT1
# 18_AT1 or 18_AT2
# 206358_AT1
# 38_AT1 or 3032_AT1 or 10449_AT1
# 30_AT1
# 30_AT1
# 30_AT1
# 84532_AT1 or 79611_AT1
# 9197_AT1
# 6566_AT1 or 9123_AT1 or 9194_AT1
# 55577_AT1
# 5238_AT1
# 6572_AT1
# 26503_AT1
# 36_AT1 or 34_AT1
# 3712_AT1
# 34_AT1 or 27034_AT1
# 51_AT1 or 51_AT2
# 95_AT1
# 50_AT1 or 48_AT1
# 52_AT1 or 52_AT3 or 52_AT2 or 55_AT1 or 51205_AT1 or 54_AT1
# 55902_AT1 or 65985_AT1 or 55902_AT2
# 438_AT1

# %%
g = model_rec3d.genes.get_by_id('55902_AT1')
g
# Out:
# <Gene 55902_AT1 at 0x2b072041850>

# %% [markdown]
# We can display the genes from the most frequent gene (present in the largest number of reactions) to the least frequent one.

# %%
d = {}

for g in model_rec3d.genes:
    d[g.name] = len(g.reactions)

# %%
G = sorted(list(d.items()), key=lambda x: x[1], reverse = True)
G[:30]
# Out:
# [('SLC7A6', 307),
#  ('SLC15A1', 252),
#  ('SLC15A2', 243),
#  ('HADHA', 168),
#  ('EHHADH', 166),
#  ('SLCO1B1', 148),
#  ('SLC27A2', 123),
#  ('ACSL1', 122),
#  ('ACAA1', 116),
#  ('SLC7A5', 115),
#  ('SLCO1A2', 106),
#  ('HADHB', 105),
#  ('CPT1A', 103),
#  ('ACOX1', 100),
#  ('ACADM', 98),
#  ('HSD17B4', 98),
#  ('ACSL5', 96),
#  ('ACSBG2', 93),
#  ('ACSL6', 93),
#  ('CPT1C', 92),
#  ('SLC25A20', 91),
#  ('ABCA1', 90),
#  ('SLC7A9', 86),
#  ('ECHS1', 84),
#  ('HADH', 81),
#  ('ACADVL', 80),
#  ('SLC16A1', 78),
#  ('ACAA2', 77),
#  ('ACSBG1', 76),
#  ('BAAT', 73)]
